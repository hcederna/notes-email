# %%
import pandas as pd
import glob


# store raw kindle notes in this directory
KINDLE_RAW_NOTES_DIRECTORY = "data/kindle/raw"

# store formatted kindle notes in this directory
KINDLE_FORMATTED_NOTES_DIRECTORY = "data/kindle/"

# %%
def extract_title_author(raw_notes_path):
    """
    Extract title and author from header of raw kindle notes csv file.
    """
    with open(raw_notes_path) as file:
        lines = file.readlines()
        # skip ",,,"
        title = lines[1].strip()[:-3].title().strip('"')
        # also skip "by "
        author = lines[2].strip()[3:-3].title().strip('"')
        return title, author

    
def create_kindle_notes_filename(title):
    """
    Return filename as title of book with "_" as spaces followed by "_notes.csv".
    
    Example:
    "ego_is_the_enemy_notes.csv"
    
    """
    return ('_').join(title.lower().split()) + "_notes.csv"


def format_kindle_notes_to_csv(raw_notes_path, formatted_notes_directory):
    """
    Format kindle notes and export to csv file with each row containing data for:
    
        - Annotation Type
        - Location
        - Starred?
        - Annotation
        - Author
        - Title

    """
    title, author = extract_title_author(raw_notes_path)

    # import notes to df without header
    notes_df = pd.read_csv(raw_notes_path, header=7)
    
    # add columns for title and author
    notes_df["Author"] = author
    notes_df["Title"] = title
    
    formatted_notes_path = formatted_notes_directory + create_kindle_notes_filename(title)
    notes_df.to_csv(formatted_notes_path, index=False)

# %%
# # store raw kindle notes in this directory
# KINDLE_RAW_NOTES_DIRECTORY = "data/kindle/raw"

# %%
# # import glob

# # grab list of raw kindle notes files
# raw_notes_paths = glob.glob(KINDLE_RAW_NOTES_DIRECTORY+'/*.csv')
# raw_notes_paths

# %%
# for raw_notes_path in raw_notes_paths:
#     format_kindle_notes_to_csv(raw_notes_path, KINDLE_FORMATTED_NOTES_DIRECTORY)

# %%
# grab list of raw kindle notes files
raw_notes_paths = glob.glob(KINDLE_RAW_NOTES_DIRECTORY+'/*.csv')

for raw_notes_path in raw_notes_paths:
    format_kindle_notes_to_csv(raw_notes_path, KINDLE_FORMATTED_NOTES_DIRECTORY)

# %%
# format_kindle_notes_to_csv("Ego Is the Enemy-Notebook - Ego Is the Enemy-Notebook.csv", KINDLE_FORMATTED_NOTES_DIRECTORY)

# %%
# # check results...
# formatted_notes_paths = glob.glob(KINDLE_FORMATTED_NOTES_DIRECTORY+'/*.csv')
# formatted_notes_paths

# %%
# check results...
formatted_notes_paths = glob.glob(KINDLE_FORMATTED_NOTES_DIRECTORY+'/*.csv')

for formatted_notes_path in formatted_notes_paths:
    print(formatted_notes_path)
    display(pd.read_csv(formatted_notes_path).sample(5))
# Out:
# data/kindle/ego_is_the_enemy_notes.csv
#         Annotation Type       Location  Starred?  \
# 59   Highlight (Yellow)  Location 1120       NaN
# 50   Highlight (Yellow)  Location 1022       NaN
# 104  Highlight (Yellow)  Location 2526       NaN
# 17   Highlight (Yellow)   Location 434       NaN
# 103  Highlight (Yellow)  Location 2499       NaN
#
#                                             Annotation        Author  \
# 59    Fac, si facis. (Do it if you’re going to do it.)  Ryan Holiday
# 50   Pride blunts the very instrument we need to ow...  Ryan Holiday
# 104  training was like sweeping the floor. Just bec...  Ryan Holiday
# 17   Almost universally, the kind of performance we...  Ryan Holiday
# 103  the old Celtic saying tells us, “See much, stu...  Ryan Holiday
#
#                 Title
# 59   Ego Is The Enemy
# 50   Ego Is The Enemy
# 104  Ego Is The Enemy
# 17   Ego Is The Enemy
# 103  Ego Is The Enemy
# data/kindle/the_inevitable:_understanding_the_12_technological_forces_that_will_shape_our_future_notes.csv
#       Annotation Type       Location  Starred?  \
# 0  Highlight (Yellow)   Location 106       NaN
# 6  Highlight (Yellow)  Location 2386       NaN
# 5  Highlight (Yellow)  Location 1464       NaN
# 4  Highlight (Yellow)   Location 211       NaN
# 3  Highlight (Yellow)   Location 208       NaN
#
#                                           Annotation        Author  \
# 0  We are morphing so fast that our ability to in...   Kevin Kelly
# 6  At this point in our history, sharing somethin...   Kevin Kelly
# 5  The link and the tag now make screening the un...   Kevin Kelly
# 4  In this era of “becoming,” everyone becomes a ...   Kevin Kelly
# 3  Technological life in the future will be a ser...   Kevin Kelly
#
#                                                Title
# 0  The Inevitable: Understanding The 12 Technolog...
# 6  The Inevitable: Understanding The 12 Technolog...
# 5  The Inevitable: Understanding The 12 Technolog...
# 4  The Inevitable: Understanding The 12 Technolog...
# 3  The Inevitable: Understanding The 12 Technolog...
# data/kindle/can't_hurt_me:_master_your_mind_and_defy_the_odds_notes.csv
#        Annotation Type  Location  Starred?  \
# 20  Highlight (Yellow)   Page 91       NaN
# 62  Highlight (Yellow)  Page 214       NaN
# 98  Highlight (Yellow)  Page 353       NaN
# 86  Highlight (Yellow)  Page 282       NaN
# 61  Highlight (Yellow)  Page 213       NaN
#
#                                            Annotation          Author  \
# 20  What the fuck? I mean, seriously, what the fuc...   David Goggins
# 62  I just wanted to quit, but by moving a little ...   David Goggins
# 98  It’s what you tell yourself that matters. The ...   David Goggins
# 86  an opportunity to be uncommon. Not that anybod...   David Goggins
# 61  every failure there is something to be gained,...   David Goggins
#
#                                                 Title
# 20  Can'T Hurt Me: Master Your Mind And Defy The Odds
# 62  Can'T Hurt Me: Master Your Mind And Defy The Odds
# 98  Can'T Hurt Me: Master Your Mind And Defy The Odds
# 86  Can'T Hurt Me: Master Your Mind And Defy The Odds
# 61  Can'T Hurt Me: Master Your Mind And Defy The Odds
