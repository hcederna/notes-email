# %%
import glob


# store formatted kindle notes in this directory
KINDLE_FORMATTED_NOTES_DIRECTORY = "data/kindle/"

# store formatted learning notes in this directory
APPLE_NOTES_FORMATTED_NOTES_DIRECTORY = "data/apple_notes"

# %%
# grab list of formatted kindle and apple notes file paths
kindle_notes_paths = glob.glob(KINDLE_FORMATTED_NOTES_DIRECTORY+'/*.csv')
apple_notes_paths = glob.glob(APPLE_NOTES_FORMATTED_NOTES_DIRECTORY+'/*.csv')
notes_paths = kindle_notes_paths + apple_notes_paths

notes_paths
# Out:
# ['data/kindle/ego_is_the_enemy_notes.csv',
#  'data/kindle/the_inevitable:_understanding_the_12_technological_forces_that_will_shape_our_future_notes.csv',
#  "data/kindle/can't_hurt_me:_master_your_mind_and_defy_the_odds_notes.csv",
#  'data/apple_notes/learning_notes.csv']

# %%
# # grab list of formatted kindle notes files
# kindle_notes_paths = glob.glob(KINDLE_FORMATTED_NOTES_DIRECTORY+'/*.csv')
# kindle_notes_paths

# %%
# # grab list of formatted apple notes files
# apple_notes_paths = glob.glob(APPLE_NOTES_FORMATTED_NOTES_DIRECTORY+'/*.csv')
# apple_notes_paths

# %%
# # create list of formatted kindle and apple notes
# notes_paths = kindle_notes_paths + apple_notes_paths
# notes_paths

# %%
import pandas as pd


# concatenate formatted notes into DataFrame
notes_dfs = [pd.read_csv(notes_path) for notes_path in notes_paths]
notes = pd.concat(notes_dfs, sort=False)

notes.head()
# Out:
#       Annotation Type      Location  Starred?  \
# 0  Highlight (Yellow)  Location 210       NaN
# 1  Highlight (Yellow)  Location 237       NaN
# 2  Highlight (Yellow)  Location 239       NaN
# 3  Highlight (Yellow)  Location 292       NaN
# 4  Highlight (Yellow)  Location 325       NaN
#
#                                           Annotation        Author  \
# 0  The ego we see most commonly goes by a more ca...  Ryan Holiday
# 1  The performance artist Marina Abramović puts i...  Ryan Holiday
# 2  Pursuing great work—whether it is in sports or...  Ryan Holiday
# 3  Ego is stolen. Confidence is earned. Ego is se...  Ryan Holiday
# 4  “abhor flatterers as you would deceivers; for ...  Ryan Holiday
#
#               Title Date
# 0  Ego Is The Enemy  NaN
# 1  Ego Is The Enemy  NaN
# 2  Ego Is The Enemy  NaN
# 3  Ego Is The Enemy  NaN
# 4  Ego Is The Enemy  NaN

# %%
NUM_NOTES = 5


# select random sample of notes
notes.sample(NUM_NOTES)
# Out:
#        Annotation Type       Location  Starred?  \
# 33  Highlight (Yellow)   Location 610       NaN
# 93  Highlight (Yellow)       Page 323       NaN
# 74  Highlight (Yellow)       Page 251       NaN
# 24  Highlight (Yellow)   Location 484       NaN
# 74  Highlight (Yellow)  Location 1455       NaN
#
#                                            Annotation          Author  \
# 33  The pretense of knowledge is our most dangerou...    Ryan Holiday
# 93  Don’t focus on what you think you deserve. Tak...   David Goggins
# 74  he makes time to get it all in by minimizing t...   David Goggins
# 24  They ignore the impulse to seek recognition be...    Ryan Holiday
# 74  All of us waste precious life doing things we ...    Ryan Holiday
#
#                                                 Title Date
# 33                                   Ego Is The Enemy  NaN
# 93  Can'T Hurt Me: Master Your Mind And Defy The Odds  NaN
# 74  Can'T Hurt Me: Master Your Mind And Defy The Odds  NaN
# ...

# %%
# import pandas as pd


# # concatenate kindle and apple notes csv files into one df
# notes_dfs = [pd.read_csv(notes_path) for notes_path in notes_paths]
# for notes_df in notes_dfs:
#     display(notes_df.sample(5))

# %%
# notes = pd.concat(notes_dfs, sort=False)
# notes.sample(10, random_state=123)

# %%
# # format email template
# for idx, row in notes.sample(3, random_state=123).iterrows():
#     print("=" * 117)
#     print()
#     print(row['Annotation'])
#     print()
#     print("-- " * 39)
#     print(f"{row['Title']} | {row['Author']} | Annotated on {row['Date']}")

# %%
# import textwrap


# WIDTH = 101


# # adjust width of text in email template
# for idx, row in notes.sample(3, random_state=123).iterrows():
#     print("=" * WIDTH)
#     print()
#     print(textwrap.fill(row['Annotation'], width=WIDTH))
#     print()
#     print("-- " * round(WIDTH/3))
#     print(textwrap.fill(f"{row['Title']} | {row['Author']} | Annotated on {row['Date']}", width=WIDTH))

# %%
# import textwrap


# WIDTH = 101


# # assemble body of email
# for idx, row in notes.sample(3).iterrows():
    
#     top_divider = "=" * WIDTH
#     annotation = textwrap.fill(row['Annotation'], width=WIDTH)
#     bottom_divider = "-- " * round(WIDTH/3)
#     citation = textwrap.fill(f"{row['Title']} | {row['Author']} | Annotated on {row['Date']}", width=WIDTH)
    
#     body = f"{top_divider}\n\n{annotation}\n\n{bottom_divider}\n{citation}"
    
#     print(body)

# %%
# import textwrap


# WIDTH = 101


# def assemble_body_of_email(notes_df, width):
#     """
#     Assemble body of email from data in notes DataFrame. Set width of text to wrap at specified width.
    
#     Format:
    
#         ============================================

#         {annotation}

#         -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#         {title} | {author} | Annotated on {date}

    
#     """
#     body = ""
    
#     for idx, row in notes_df.iterrows():

#         top_divider = "=" * WIDTH
#         annotation = textwrap.fill(row['Annotation'], width=WIDTH)
#         bottom_divider = "-- " * round(WIDTH/3)
#         citation = textwrap.fill(f"{row['Title']} | {row['Author']} | Annotated on {row['Date']}", width=WIDTH)

#         body = body + f"{top_divider}\n\n{annotation}\n\n{bottom_divider}\n{citation}\n"
    
#     body += top_divider

#     return(body)

# %%
# print(assemble_body_of_email(notes.sample(NUM_NOTES), WIDTH))
# Out:
# ...
#
# “It’s not with ideas, my dear Degas, that one makes verse. It’s with words.” Or rather, with work.
#
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
# Ego Is The Enemy | Ryan Holiday | Annotated on nan
# ...
#
# Most, if not all, minorities, women, and gay people in America know that strain of loneliness well.
# Of walking into rooms where you are the only one of your kind. Most white men have no idea how hard
# it can be. I wish they did. Because then they’d know how it drains you.
#
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
# Can'T Hurt Me: Master Your Mind And Defy The Odds |  David Goggins | Annotated on nan
# ...
#
# It’s about the doing, not the recognition.
#
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
# Ego Is The Enemy | Ryan Holiday | Annotated on nan
# ...
#
# ...

# %%
# ##### THIS WORKS
# # plain text version
# import smtplib
# from email.message import EmailMessage

# from config import gmail_user, gmail_password, recipient_emails


# msg = EmailMessage()

# msg['Subject'] = "Notes Digest"
# msg['From'] = gmail_user
# msg['To'] = recipient_emails
# msg.add_header('Content-Type','text/html')
# msg.set_content(assemble_body_of_email(notes.sample(NUM_NOTES), WIDTH))

# server = smtplib.SMTP_SSL('smtp.gmail.com')
# server.ehlo()
# server.login(gmail_user, gmail_password)
# server.send_message(msg)
# server.quit()
# Out:
# (221, b'2.0.0 closing connection 143sm637108pfz.67 - gsmtp')

# %%
notes_df = notes.sample(NUM_NOTES)

# %%
def assemble_html_body_of_email(notes_df):
    """
    Assemble body of email from data in notes DataFrame.
    
    Format:
    
        ============================================

        {annotation}

        -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
        {title} | {author} | Annotated on {date}

    
    """
    
    body = """\
    <html>
      <head></head>
      <body>
    """

    for idx, row in notes_df.iterrows():

        annotation = row['Annotation']
        citation = f"{row['Title']} | {row['Author']} | Annotated on {row['Date']}"

        body = body + f"""\
        <p>
          <hr style="border: 5px solid grey">
          <br>
          {annotation}
          <br>
          <br>
          <hr style="border: 1px dashed grey">
          <blockquote><i>{citation}</i></blockquote>
        </p>
        """

    body += f"""\
      <hr style="border: 5px solid grey">
      </body>
    </html>
    """
    
    return(body)

print(assemble_html_body_of_email(notes_df))
# Out:
#     <html>
#       <head></head>
#       <body>
#             <p>
#           <hr style="border: 5px solid grey">
#           <br>
#           There is a sort of ego ceiling imposed—one knows that he is not better than the “master” he apprentices under.
#           <br>
#           <br>
#           <hr style="border: 1px dashed grey">
#           <blockquote><i>Ego Is The Enemy | Ryan Holiday | Annotated on nan</i></blockquote>
#         </p>
#                 <p>
#           <hr style="border: 5px solid grey">
#           <br>
#           “I am going to be myself, the best version of that self. I am in this for the long game, no matter how brutal it might be.” To do, not be.
#           <br>
#           <br>
#           <hr style="border: 1px dashed grey">
#           <blockquote><i>Ego Is The Enemy | Ryan Holiday | Annotated on nan</i></blockquote>
#         </p>
#                 <p>
#           <hr style="border: 5px solid grey">
#           <br>
# ...

# %%
import smtplib

from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText

from config import gmail_user, gmail_password, recipient_emails


msg = MIMEMultipart('alternative')
msg['Subject'] = "Notes Digest"
msg['From'] = gmail_user
msg['To'] = 'hcederna@gmail.com'

body = assemble_html_body_of_email(notes_df)
msg.attach(MIMEText(body, 'html'))
                                                               
server = smtplib.SMTP_SSL('smtp.gmail.com')
server.ehlo()
server.login(gmail_user, gmail_password)
server.sendmail(gmail_user, 'hcederna@gmail.com', msg.as_string())
server.quit()
# Out:
# (221, b'2.0.0 closing connection d22sm3972032pgg.52 - gsmtp')

# %%
# # THIS WORKS
# import smtplib

# from email.mime.multipart import MIMEMultipart
# from email.mime.text import MIMEText


# msg = MIMEMultipart('alternative')
# msg['Subject'] = "Notes Digest"
# msg['From'] = gmail_user
# msg['To'] = 'hcederna@gmail.com'

# # text = assemble_body_of_email(notes_df, WIDTH)

# body = """\
# <html>
#   <head></head>
#   <body>
# """

# for idx, row in notes_df.iterrows():

#     annotation = row['Annotation']
#     citation = f"{row['Title']} | {row['Author']} | Annotated on {row['Date']}"

#     body = body + f"""\
#     <p>
#       <hr style="border: 5px solid grey">
#       <br>
#       {annotation}
#       <br>
#       <br>
#       <hr style="border: 1px dashed grey">
#       <blockquote><i>{citation}</i></blockquote>
#     </p>
#     """

# body += f"""\
#   <hr style="border: 5px solid grey">
#   </body>
# </html>
# """
                             
# html = body
                             
# # Record the MIME types of both parts - text/plain and text/html.
# # part1 = MIMEText(text, 'plain')
# part2 = MIMEText(html, 'html')

# # Attach parts into message container.
# # According to RFC 2046, the last part of a multipart message, in this case
# # the HTML message, is best and preferred.
# # msg.attach(part1)
# msg.attach(part2)
                                     
                             
# server = smtplib.SMTP_SSL('smtp.gmail.com')
# server.ehlo()
# server.login(gmail_user, gmail_password)
# server.sendmail(gmail_user, 'hcederna@gmail.com', msg.as_string())
# server.quit()
# Out:
# (221, b'2.0.0 closing connection y76sm4419658pfc.87 - gsmtp')
